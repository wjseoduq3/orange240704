# %%
import pandas as pd

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
submission= pd.read_csv("data/sampleSubmission.csv")

# %%
### 이상치 제거

train = train[train['weather'] !=4]
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.shape
# Out:
# (10885, 12)

# %%
test.shape
# Out:
# (6493, 9)

# %%
all_data_temp = pd.concat([train, test])

# %%
all_data = all_data_temp = pd.concat([train, test], ignore_index=True )

# %%
all_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0     3.0        13.0   16.0
# 1        80        0.0     8.0        32.0   40.0
# 2        80        0.0     5.0        27.0   32.0
# 3        75        0.0     3.0        10.0   13.0
# 4        75        0.0     0.0         1.0    1.0

# %%
from datetime import datetime
import calendar

# %%
from datetime import datetime

all_data['date']=all_data['datetime'].apply(lambda x:x.split()[0])
all_data['year']=all_data['datetime'].apply(lambda x:x.split()[0].split('-')[0])
all_data['month']=all_data['datetime'].apply(lambda x:x.split()[0].split('-')[1])
all_data['day']=all_data['datetime'].apply(lambda x:x.split()[0].split('-')[2])
all_data['hour']=all_data['datetime'].apply(lambda x:x.split()[1].split(':')[0])
all_data['min']=all_data['datetime'].apply(lambda x:x.split()[1].split(':')[1])
all_data['sec']=all_data['datetime'].apply(lambda x:x.split()[1].split(':')[2])

all_data['weekday'] = all_data['date'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d').weekday())

# %%
all_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 17373  2012-12-31 19:00:00       1        0           1        2  10.66
# 17374  2012-12-31 20:00:00       1        0           1        2  10.66
# 17375  2012-12-31 21:00:00       1        0           1        1  10.66
# 17376  2012-12-31 22:00:00       1        0           1        1  10.66
# 17377  2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count        date  \
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17378 entries, 0 to 17377
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    17378 non-null  object
#  1   season      17378 non-null  int64
#  2   holiday     17378 non-null  int64
#  3   workingday  17378 non-null  int64
#  4   weather     17378 non-null  int64
#  5   temp        17378 non-null  float64
#  6   atemp       17378 non-null  float64
#  7   humidity    17378 non-null  int64
#  8   windspeed   17378 non-null  float64
#  9   casual      10885 non-null  float64
#  10  registered  10885 non-null  float64
#  11  count       10885 non-null  float64
#  12  date        17378 non-null  object
#  13  year        17378 non-null  object
#  14  month       17378 non-null  object
#  15  day         17378 non-null  object
#  16  hour        17378 non-null  object
#  17  min         17378 non-null  object
#  18  sec         17378 non-null  object
# ...

# %%
drop_features=['datetime', 'date', 'min', 'sec', 'windspeed','casual','registered']
all_data = all_data.drop(drop_features, axis=1)
all_data
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  count  \
# 0           1        0           0        1   9.84  14.395        81   16.0
# 1           1        0           0        1   9.02  13.635        80   40.0
# 2           1        0           0        1   9.02  13.635        80   32.0
# 3           1        0           0        1   9.84  14.395        75   13.0
# 4           1        0           0        1   9.84  14.395        75    1.0
# ...       ...      ...         ...      ...    ...     ...       ...    ...
# 17373       1        0           1        2  10.66  12.880        60    NaN
# 17374       1        0           1        2  10.66  12.880        60    NaN
# 17375       1        0           1        1  10.66  12.880        60    NaN
# 17376       1        0           1        1  10.66  13.635        56    NaN
# 17377       1        0           1        1  10.66  13.635        65    NaN
#
#        year month day hour  weekday
# ...

# %%
X_train = all_data[~pd.isnull(all_data['count'])]
X_test = all_data[pd.isnull(all_data['count'])]

X_train = X_train.drop(['count'], axis=1)
X_test = X_test.drop(['count'], axis=1)

y_true=train['count']

# %%
X_train.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  year month  \
# 0       1        0           0        1  9.84  14.395        81  2011    01
# 1       1        0           0        1  9.02  13.635        80  2011    01
# 2       1        0           0        1  9.02  13.635        80  2011    01
# 3       1        0           0        1  9.84  14.395        75  2011    01
# 4       1        0           0        1  9.84  14.395        75  2011    01
#
#   day hour  weekday
# 0  01   00        5
# 1  01   01        5
# 2  01   02        5
# 3  01   03        5
# 4  01   04        5

# %%
X_test.head()
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  year  \
# 10885       1        0           1        1  10.66  11.365        56  2011
# 10886       1        0           1        1  10.66  13.635        56  2011
# 10887       1        0           1        1  10.66  13.635        56  2011
# 10888       1        0           1        1  10.66  12.880        56  2011
# 10889       1        0           1        1  10.66  12.880        56  2011
#
#       month day hour  weekday
# 10885    01  20   00        3
# 10886    01  20   01        3
# 10887    01  20   02        3
# 10888    01  20   03        3
# 10889    01  20   04        3

# %%
y_true.head()
# Out:
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
y_true.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10885 entries, 0 to 10885
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 10885 non-null  int64
# dtypes: int64(1)
# memory usage: 170.1 KB

# %%
import numpy as np
def rmsle(y_true, y_pred, convertExp=True):
    # 지수변환 ①
    if convertExp:
       y_true = np.exp(y_true)
       y_pred = np.exp(y_pred)

    # 로그변환 후 결측값을 0으로 변환 ②
    log_true = np.nan_to_num(np.log(y_true+1))
    log_pred = np.nan_to_num(np.log(y_pred+1))

    # RMSLE 계산 ③
    output = np.sqrt(np.mean((log_true - log_pred)**2))
    return output

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
# from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

linear_reg_model = LinearRegression()

log_y =np.log(y_true)

linear_reg_model.fit(X_train, log_y)
# Out:
# LinearRegression()

# %%
pred=linear_reg_model.predict(X_train)
print(f'RMSE: {rmsle(log_y,pred,True)}')
# Out:
# RMSE: 1.0184696944744123

# %%
### 예측 결과

real_pred=linear_reg_model.predict(X_test)
# print(real_pred)
submission['count'] = np.exp(real_pred)
submission.to_csv("D:/JDY_folder/vs_ws/orange240704/data/submission.csv", index=False)
